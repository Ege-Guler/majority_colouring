# %%
using DotEnv
DotEnv.config() 

using JuMP
using Gurobi

model = Model(Gurobi.Optimizer)

# Simple test to confirm it works
@variable(model, x >= 0)
@objective(model, Min, x)
optimize!(model)

if termination_status(model) == OPTIMAL
    println("Gurobi is licensed and running!")
end
# Out:
# Gurobi Error 10009: No Gurobi license found (user ege, host athena, hostid ba74a6d8, cores 12)
#
# Stacktrace:
#   [1] _check_ret
#     @ ~/.julia/packages/Gurobi/K2XSK/src/MOI_wrapper/MOI_wrapper.jl:442 [inlined]
#   [2] Gurobi.Env(params::Nothing; started::Bool, output_flag::Int64, memory_limit::Nothing)
#     @ Gurobi ~/.julia/packages/Gurobi/K2XSK/src/MOI_wrapper/MOI_wrapper.jl:176
#   [3] Env (repeats 2 times)
#     @ ~/.julia/packages/Gurobi/K2XSK/src/MOI_wrapper/MOI_wrapper.jl:143 [inlined]
#   [4] Gurobi.Optimizer(env::Nothing; enable_interrupts::Bool)
#     @ Gurobi ~/.julia/packages/Gurobi/K2XSK/src/MOI_wrapper/MOI_wrapper.jl:372
#   [5] Optimizer
#     @ ~/.julia/packages/Gurobi/K2XSK/src/MOI_wrapper/MOI_wrapper.jl:366 [inlined]
#   [6] Gurobi.Optimizer()
#     @ Gurobi ~/.julia/packages/Gurobi/K2XSK/src/MOI_wrapper/MOI_wrapper.jl:366
#   [7] _instantiate_and_check(optimizer_constructor::Any)
#     @ MathOptInterface ~/.julia/packages/MathOptInterface/Q3V1z/src/instantiate.jl:96
#   [8] instantiate(optimizer_constructor::Any; with_bridge_type::Type{Float64}, with_cache_type::Nothing)
#     @ MathOptInterface ~/.julia/packages/MathOptInterface/Q3V1z/src/instantiate.jl:177
#   [9] set_optimizer(model::Model, optimizer_constructor::Any; add_bridges::Bool, kwargs::@Kwargs{})
#     @ JuMP ~/.julia/packages/JuMP/7eD71/src/optimizer_interface.jl:503
#  [10] set_optimizer
#     @ ~/.julia/packages/JuMP/7eD71/src/optimizer_interface.jl:495 [inlined]
#  [11] Model(optimizer_factory::Any; kwargs::@Kwargs{})
#     @ JuMP ~/.julia/packages/JuMP/7eD71/src/JuMP.jl:204
#  [12] Model(optimizer_factory::Any)
#     @ JuMP ~/.julia/packages/JuMP/7eD71/src/JuMP.jl:196
#  [13] top-level scope
#     @ In[6]:7
#  [14] eval(m::Module, e::Any)
#     @ Core ./boot.jl:489
